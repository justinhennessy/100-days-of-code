# %% [markdown]
# **Important: This notebook will only work with fastai-0.7.x. Do not try to run any fastai-1.x code from this path in the repository because it will load fastai-0.7.x**

# %% [markdown]
# # Neto customer churn predict project

# %% [markdown]
# ## Summary
#
# This is a data project to see if we can take customer data from the Neto platform and categorise and hopefully in the end "predict" when a customer is likely to churn. There will be a heap of assumptions which I will note in here.
#
# ### Research links
#
# https://www.kaggle.com/pavanraj159/telecom-customer-churn-prediction/data

# %% [markdown]
# ### Assumptions
#
# - churn can be indicated by last login date of an account
# - usage behaviour of a customers use of the export system could indicate signs of churn

# %% [markdown]
# ### Data observation
#
# `Neto License Registration Date` and `Go Live Date` are sometime entered "backwards" so when calulating the `go live days` I am taking the absolute value so I dont get a negative value.
#
# `go live day` - if they are not `LIVE` I set the value to `-1` so we know its not live yet, 0 is a valid period of days.
#
# `canceldate` - is not always in the future so I have had to get absolute values when calculating days active

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %matplotlib inline

# %%
import numpy as np
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display


from sklearn import metrics

# %%
PATH = "../../data/"

# %%
# !ls {PATH}
# Out:
# Data Dictionary.xlsx             churn.csv
# Machine_Appendix.csv             human_numbers.tgz
# Test.csv                         median_benchmark.csv
# adult_sample.tgz                 random_forest_benchmark_test.csv
# bulldozers                       test

# %%
df_raw = pd.read_csv(f'{PATH}churn.csv', low_memory=False, 
                     parse_dates=["canceldate", "licence_registration_date", "golive_date"])

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
df_raw.describe(include='all')
# Out:
#        username  merchant           canceldate licence_registration_date  \
# count      5889      5885                 5889                      5889
# unique     5889      5778                  913                      1529
# top     N001086  Invertek  1970-01-01 00:00:00       2013-11-25 00:00:00
# freq          1         5                 2776                       126
# first       NaN       NaN  1970-01-01 00:00:00       2010-07-03 00:00:00
# last        NaN       NaN  2019-09-06 00:00:00       2019-09-06 00:00:00
# mean        NaN       NaN                  NaN                       NaN
# std         NaN       NaN                  NaN                       NaN
# min         NaN       NaN                  NaN                       NaN
# 25%         NaN       NaN                  NaN                       NaN
# 50%         NaN       NaN                  NaN                       NaN
# 75%         NaN       NaN                  NaN                       NaN
# max         NaN       NaN                  NaN                       NaN
#
#         days_active  last_active_days account_status         nps  \
# count   5889.000000       3121.000000           3128  513.000000
# unique          NaN               NaN              5         NaN
# top             NaN               NaN         Active         NaN
# freq            NaN               NaN           2643         NaN
# first           NaN               NaN            NaN         NaN
# last            NaN               NaN            NaN         NaN
# mean     673.074036         26.166293            NaN    4.337232
# std      561.863296         59.673295            NaN    3.536268
# min        0.000000          0.000000            NaN    0.000000
# 25%      191.000000          0.000000            NaN    1.000000
# 50%      519.000000          0.000000            NaN    5.000000
# 75%     1037.000000         13.000000            NaN    7.000000
# max     2251.000000        417.000000            NaN   10.000000
#
#        licence_status       cancel_reason  ...        plans         plan  \
# count            5889                3111  ...         5884         5884
# unique              4                  18  ...           42           42
# top         CANCELLED  Non-payment (Neto)  ...  PLAN-S-19Q1  PLAN-S-19Q1
# freq             3109                 621  ...         1530         1530
# first             NaN                 NaN  ...          NaN          NaN
# last              NaN                 NaN  ...          NaN          NaN
# mean              NaN                 NaN  ...          NaN          NaN
# std               NaN                 NaN  ...          NaN          NaN
# min               NaN                 NaN  ...          NaN          NaN
# 25%               NaN                 NaN  ...          NaN          NaN
# 50%               NaN                 NaN  ...          NaN          NaN
# 75%               NaN                 NaN  ...          NaN          NaN
# max               NaN                 NaN  ...          NaN          NaN
#
#        changing_platform new_platform salesperson          golive_date  \
# count               1821          738        5889                 5889
# unique                 2          121          26                  936
# top                   No      Shopify        rene  1970-01-01 00:00:00
# freq                1073          189         943                 2706
# first                NaN          NaN         NaN  1970-01-01 00:00:00
# last                 NaN          NaN         NaN  2019-06-12 00:00:00
# mean                 NaN          NaN         NaN                  NaN
# std                  NaN          NaN         NaN                  NaN
# min                  NaN          NaN         NaN                  NaN
# 25%                  NaN          NaN         NaN                  NaN
# 50%                  NaN          NaN         NaN                  NaN
# 75%                  NaN          NaN         NaN                  NaN
# max                  NaN          NaN         NaN                  NaN
#
#         golive_days                               url      churned  \
# count   5889.000000                              5884  5889.000000
# unique          NaN                              5852          NaN
# top             NaN  www.southerncrossemporium.com.au          NaN
# freq            NaN                                 4          NaN
# first           NaN                               NaN          NaN
# last            NaN                               NaN          NaN
# mean      67.630328                               NaN     0.527933
# std      142.993069                               NaN     0.499262
# min       -1.000000                               NaN     0.000000
# 25%       -1.000000                               NaN     0.000000
# 50%        4.000000                               NaN     1.000000
# 75%       74.000000                               NaN     1.000000
# max     1643.000000                               NaN     1.000000
#
#         churn_concern
# count     3276.000000
# unique            NaN
# top               NaN
# freq              NaN
# first             NaN
# last              NaN
# mean         0.954823
# std          0.207724
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
#
# [13 rows x 23 columns]

# %% [markdown]
# ### Initial processing

# %% [markdown]
# This dataset contains a mix of **continuous** and **categorical** variables.
#
# The following method extracts particular date fields from a complete datetime for the purpose of constructing categoricals.  You should always consider this feature extraction step when working with date-time. Without expanding your date-time into these additional fields, you can't capture any trend/cyclical behavior as a function of time at any of these granularities.

# %%
# These steps can only be run once then you need to comment them out

#add_datepart(df_raw, 'canceldate')
add_datepart(df_raw, 'licence_registration_date')
add_datepart(df_raw, 'golive_date')

# %% [markdown]
# The code above breaks up all of the dates fields into a bunch of different fields, displayed below.

# %% [markdown]
# The categorical variables are currently stored as strings, which is inefficient, and doesn't provide the numeric coding required for a random forest. Therefore we call `train_cats` to convert strings to pandas categories.

# %%
df_raw = df_raw.drop(columns=['licence_status','account_status', 'canceldate', 'cancel_details', 'cancel_reason', 'changing_platform'])

# %%
train_cats(df_raw)

# %% [markdown]
# This fills all NaN values in the follow fields with that columns mean.

# %%
df_raw.nps = df_raw.nps.fillna(np.nanmean(df_raw.nps))
df_raw.last_active_days = df_raw.last_active_days.fillna(np.mean(df_raw.last_active_days))
df_raw.churn_concern = df_raw.churn_concern.fillna(0)
display_all(df_raw)
# Out:
#          username                  merchant  days_active  last_active_days  \
# 0     NoveltyShop          The Novelty Shop         1851         26.166293
# 1         N002341                  Mx Store         2251          0.000000
# 2         N001714               Just Health         2250          1.000000
# 3         N002628  Barefoot Healing Pty Ltd         2250          0.000000
# 4         N002758  Aussie Fitness Equipment         2195          0.000000
# ...           ...                       ...          ...               ...
# 5884      N065838          Thryve Nutrition           10          0.000000
# 5885      N066053             McMullin & co           10          0.000000
# 5886      N065608                 McsOnline            9          0.000000
# 5887      N066090     MX Online Australia 2            9          0.000000
# 5888      N065924             PPF Solutions            8          0.000000
#
#            nps           team              vertical         plans  \
# 0     4.337232  not specified         not specified  BUSINESS ONE
# 1     4.337232        Neto XL   Sports & Recreation  PLAN-XL-19Q1
# 2     7.000000  not specified       Health & Beauty   PLAN-S-19Q1
# 3     4.337232  not specified       Health & Beauty   PLAN-L-19Q1
# 4     4.337232  not specified   Sports & Recreation   PLAN-L-19Q1
# ...        ...            ...                   ...           ...
# 5884  4.337232   Team Imagine  Supplements & Nutrit   PLAN-M-19Q1
# 5885  4.337232    Team Vision             Homewares   PLAN-M-19Q1
# 5886  4.337232        Neto XL           Motor Parts   PLAN-S-19Q1
# 5887  4.337232        Neto XL           Motor Parts   PLAN-L-19Q1
# 5888  4.337232    Team Vision           Motor Parts   PLAN-S-19Q1
#
#               plan new_platform    salesperson  golive_days  \
# 0     BUSINESS ONE          NaN        dominic           -1
# 1     PLAN-XL-19Q1          NaN  not specified           -1
# 2      PLAN-S-19Q1          NaN            cat           -1
# 3      PLAN-L-19Q1          NaN  not specified           -1
# 4      PLAN-L-19Q1          NaN           rene           -1
# ...            ...          ...            ...          ...
# 5884   PLAN-M-19Q1          NaN    simon.white           -1
# 5885   PLAN-M-19Q1          NaN    simon.white           -1
# 5886   PLAN-S-19Q1          NaN    simon.white           -1
# 5887   PLAN-L-19Q1          NaN    simon.white           -1
# 5888   PLAN-S-19Q1          NaN    simon.white           -1
#
#                                 url  churned  churn_concern  \
# 0                               NaN        1            1.0
# 1                www.mxstore.com.au        0            0.0
# 2            www.just-health.com.au        0            0.0
# 3        www.barefoothealing.com.au        0            0.0
# 4          www.aussiefitness.com.au        0            0.0
# ...                             ...      ...            ...
# 5884    thryve-nutritio.neto.com.au        0            0.0
# 5885      mcmullinandco.neto.com.au        0            0.0
# 5886          mcsonline.neto.com.au        0            0.0
# 5887  mx-online-austr-1.neto.com.au        0            0.0
# 5888      ppf-solutions.neto.com.au        0            0.0
#
#       licence_registration_Year  licence_registration_Month  \
# 0                          2010                           7
# 1                          2013                           7
# 2                          2013                           7
# 3                          2013                           7
# 4                          2013                           9
# ...                         ...                         ...
# 5884                       2019                           9
# 5885                       2019                           9
# 5886                       2019                           9
# 5887                       2019                           9
# 5888                       2019                           9
#
#       licence_registration_Week  licence_registration_Day  \
# 0                            26                         3
# 1                            29                        16
# 2                            29                        17
# 3                            29                        17
# 4                            37                        10
# ...                         ...                       ...
# 5884                         36                         4
# 5885                         36                         4
# 5886                         36                         5
# 5887                         36                         5
# 5888                         36                         6
#
#       licence_registration_Dayofweek  licence_registration_Dayofyear  \
# 0                                  5                             184
# 1                                  1                             197
# 2                                  2                             198
# 3                                  2                             198
# 4                                  1                             253
# ...                              ...                             ...
# 5884                               2                             247
# 5885                               2                             247
# 5886                               3                             248
# 5887                               3                             248
# 5888                               4                             249
#
#       licence_registration_Is_month_end  licence_registration_Is_month_start  \
# 0                                 False                                False
# 1                                 False                                False
# 2                                 False                                False
# 3                                 False                                False
# 4                                 False                                False
# ...                                 ...                                  ...
# 5884                              False                                False
# 5885                              False                                False
# 5886                              False                                False
# 5887                              False                                False
# 5888                              False                                False
#
#       licence_registration_Is_quarter_end  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 5884                                False
# 5885                                False
# 5886                                False
# 5887                                False
# 5888                                False
#
#       licence_registration_Is_quarter_start  licence_registration_Is_year_end  \
# 0                                     False                             False
# 1                                     False                             False
# 2                                     False                             False
# 3                                     False                             False
# 4                                     False                             False
# ...                                     ...                               ...
# 5884                                  False                             False
# 5885                                  False                             False
# 5886                                  False                             False
# 5887                                  False                             False
# 5888                                  False                             False
#
#       licence_registration_Is_year_start  licence_registration_Elapsed  \
# 0                                  False                    1278115200
# 1                                  False                    1373932800
# 2                                  False                    1374019200
# 3                                  False                    1374019200
# 4                                  False                    1378771200
# ...                                  ...                           ...
# 5884                               False                    1567555200
# 5885                               False                    1567555200
# 5886                               False                    1567641600
# 5887                               False                    1567641600
# 5888                               False                    1567728000
#
#       golive_Year  golive_Month  golive_Week  golive_Day  golive_Dayofweek  \
# 0            1970             1            1           1                 3
# 1            1970             1            1           1                 3
# 2            1970             1            1           1                 3
# 3            1970             1            1           1                 3
# 4            1970             1            1           1                 3
# ...           ...           ...          ...         ...               ...
# 5884         1970             1            1           1                 3
# 5885         1970             1            1           1                 3
# 5886         1970             1            1           1                 3
# 5887         1970             1            1           1                 3
# 5888         1970             1            1           1                 3
#
#       golive_Dayofyear  golive_Is_month_end  golive_Is_month_start  \
# 0                    1                False                   True
# 1                    1                False                   True
# 2                    1                False                   True
# 3                    1                False                   True
# 4                    1                False                   True
# ...                ...                  ...                    ...
# 5884                 1                False                   True
# 5885                 1                False                   True
# 5886                 1                False                   True
# 5887                 1                False                   True
# 5888                 1                False                   True
#
#       golive_Is_quarter_end  golive_Is_quarter_start  golive_Is_year_end  \
# 0                     False                     True               False
# 1                     False                     True               False
# 2                     False                     True               False
# 3                     False                     True               False
# 4                     False                     True               False
# ...                     ...                      ...                 ...
# 5884                  False                     True               False
# 5885                  False                     True               False
# 5886                  False                     True               False
# 5887                  False                     True               False
# 5888                  False                     True               False
#
#       golive_Is_year_start  golive_Elapsed
# 0                     True               0
# 1                     True               0
# 2                     True               0
# 3                     True               0
# 4                     True               0
# ...                    ...             ...
# 5884                  True               0
# 5885                  True               0
# 5886                  True               0
# 5887                  True               0
# 5888                  True               0
#
# [5889 rows x 41 columns]

# %% [markdown]
# But let's save this file for now, since it's already in format can we be stored and accessed efficiently.

# %%
df_raw.columns
# Out:
# Index(['username', 'merchant', 'days_active', 'last_active_days', 'nps',
#        'team', 'vertical', 'plans', 'plan', 'new_platform', 'salesperson',
#        'golive_days', 'url', 'churned', 'churn_concern',
#        'licence_registration_Year', 'licence_registration_Month',
#        'licence_registration_Week', 'licence_registration_Day',
#        'licence_registration_Dayofweek', 'licence_registration_Dayofyear',
#        'licence_registration_Is_month_end',
#        'licence_registration_Is_month_start',
#        'licence_registration_Is_quarter_end',
#        'licence_registration_Is_quarter_start',
#        'licence_registration_Is_year_end',
#        'licence_registration_Is_year_start', 'licence_registration_Elapsed',
#        'golive_Year', 'golive_Month', 'golive_Week', 'golive_Day',
#        'golive_Dayofweek', 'golive_Dayofyear', 'golive_Is_month_end',
#        'golive_Is_month_start', 'golive_Is_quarter_end',
#        'golive_Is_quarter_start', 'golive_Is_year_end', 'golive_Is_year_start',
#        'golive_Elapsed'],
#       dtype='object')

# %%
df, y, nas = proc_df(df_raw, 'churned', max_n_cat=5)
display_all(df)
# Out:
#       username  merchant  days_active  last_active_days       nps  team  \
# 0         5750      4978         1851         26.166293  4.337232    14
# 1          256      3300         2251          0.000000  4.337232     4
# 2          222      2612         2250          1.000000  7.000000    14
# 3          273       612         2250          0.000000  4.337232    14
# 4          285       434         2195          0.000000  4.337232    14
# ...        ...       ...          ...               ...       ...   ...
# 5884      5729      5058           10          0.000000  4.337232     8
# 5885      5746      3090           10          0.000000  4.337232     9
# 5886      5712      3091            9          0.000000  4.337232     4
# 5887      5747      2978            9          0.000000  4.337232     4
# 5888      5738      3680            8          0.000000  4.337232     9
#
#       vertical  plans  plan  new_platform  salesperson  golive_days   url  \
# 0           26      5     5             0           11           -1     0
# 1           20     33    33             0           18           -1  4405
# 2            8     31    31             0            8           -1  3971
# 3            8     23    23             0           18           -1  2686
# 4           20     23    23             0           20           -1  2605
# ...        ...    ...   ...           ...          ...          ...   ...
# 5884        21     27    27             0           24           -1  2143
# 5885        10     27    27             0           24           -1  1246
# 5886        15     31    31             0           24           -1  1249
# 5887        15     23    23             0           24           -1  1343
# 5888        15     31    31             0           24           -1  1588
#
#       churn_concern  licence_registration_Year  licence_registration_Month  \
# 0               1.0                       2010                           7
# 1               0.0                       2013                           7
# 2               0.0                       2013                           7
# 3               0.0                       2013                           7
# 4               0.0                       2013                           9
# ...             ...                        ...                         ...
# 5884            0.0                       2019                           9
# 5885            0.0                       2019                           9
# 5886            0.0                       2019                           9
# 5887            0.0                       2019                           9
# 5888            0.0                       2019                           9
#
#       licence_registration_Week  licence_registration_Day  \
# 0                            26                         3
# 1                            29                        16
# 2                            29                        17
# 3                            29                        17
# 4                            37                        10
# ...                         ...                       ...
# 5884                         36                         4
# 5885                         36                         4
# 5886                         36                         5
# 5887                         36                         5
# 5888                         36                         6
#
#       licence_registration_Dayofweek  licence_registration_Dayofyear  \
# 0                                  5                             184
# 1                                  1                             197
# 2                                  2                             198
# 3                                  2                             198
# 4                                  1                             253
# ...                              ...                             ...
# 5884                               2                             247
# 5885                               2                             247
# 5886                               3                             248
# 5887                               3                             248
# 5888                               4                             249
#
#       licence_registration_Is_month_end  licence_registration_Is_month_start  \
# 0                                 False                                False
# 1                                 False                                False
# 2                                 False                                False
# 3                                 False                                False
# 4                                 False                                False
# ...                                 ...                                  ...
# 5884                              False                                False
# 5885                              False                                False
# 5886                              False                                False
# 5887                              False                                False
# 5888                              False                                False
#
#       licence_registration_Is_quarter_end  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 5884                                False
# 5885                                False
# 5886                                False
# 5887                                False
# 5888                                False
#
#       licence_registration_Is_quarter_start  licence_registration_Is_year_end  \
# 0                                     False                             False
# 1                                     False                             False
# 2                                     False                             False
# 3                                     False                             False
# 4                                     False                             False
# ...                                     ...                               ...
# 5884                                  False                             False
# 5885                                  False                             False
# 5886                                  False                             False
# 5887                                  False                             False
# 5888                                  False                             False
#
#       licence_registration_Is_year_start  licence_registration_Elapsed  \
# 0                                  False                    1278115200
# 1                                  False                    1373932800
# 2                                  False                    1374019200
# 3                                  False                    1374019200
# 4                                  False                    1378771200
# ...                                  ...                           ...
# 5884                               False                    1567555200
# 5885                               False                    1567555200
# 5886                               False                    1567641600
# 5887                               False                    1567641600
# 5888                               False                    1567728000
#
#       golive_Year  golive_Month  golive_Week  golive_Day  golive_Dayofweek  \
# 0            1970             1            1           1                 3
# 1            1970             1            1           1                 3
# 2            1970             1            1           1                 3
# 3            1970             1            1           1                 3
# 4            1970             1            1           1                 3
# ...           ...           ...          ...         ...               ...
# 5884         1970             1            1           1                 3
# 5885         1970             1            1           1                 3
# 5886         1970             1            1           1                 3
# 5887         1970             1            1           1                 3
# 5888         1970             1            1           1                 3
#
#       golive_Dayofyear  golive_Is_month_end  golive_Is_month_start  \
# 0                    1                False                   True
# 1                    1                False                   True
# 2                    1                False                   True
# 3                    1                False                   True
# 4                    1                False                   True
# ...                ...                  ...                    ...
# 5884                 1                False                   True
# 5885                 1                False                   True
# 5886                 1                False                   True
# 5887                 1                False                   True
# 5888                 1                False                   True
#
#       golive_Is_quarter_end  golive_Is_quarter_start  golive_Is_year_end  \
# 0                     False                     True               False
# 1                     False                     True               False
# 2                     False                     True               False
# 3                     False                     True               False
# 4                     False                     True               False
# ...                     ...                      ...                 ...
# 5884                  False                     True               False
# 5885                  False                     True               False
# 5886                  False                     True               False
# 5887                  False                     True               False
# 5888                  False                     True               False
#
#       golive_Is_year_start  golive_Elapsed
# 0                     True               0
# 1                     True               0
# 2                     True               0
# 3                     True               0
# 4                     True               0
# ...                    ...             ...
# 5884                  True               0
# 5885                  True               0
# 5886                  True               0
# 5887                  True               0
# 5888                  True               0
#
# [5889 rows x 40 columns]

# %%
# This is how to save the current data set

os.makedirs('tmp', exist_ok=True)
df_raw.to_feather('tmp/churn')

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# In the future we can simply read it from this fast format.

# %%
df_raw = pd.read_feather('tmp/churn')

# %% [markdown]
# We'll replace categories with their numeric codes, handle missing continuous values, and split the dependent variable into a separate variable.

# %%
df, y, nas = proc_df(df_raw, 'churned')

# %%
display_all(df)
# Out:
#       username  merchant  days_active  last_active_days  is_suspended  \
# 0         5750      4978         1851         26.166293           0.0
# 1          256      3300         2248          0.000000           0.0
# 2          222      2612         2247          1.000000           0.0
# 3          273       612         2247          0.000000           0.0
# 4          285       434         2192          0.000000           0.0
# ...        ...       ...          ...               ...           ...
# 5884      5729      5058            7          0.000000           0.0
# 5885      5746      3090            7          0.000000           0.0
# 5886      5712      3091            6          0.000000           0.0
# 5887      5747      2978            6          0.000000           0.0
# 5888      5738      3680            5          0.000000           0.0
#
#            nps  cancel_reason  cancel_details  team  vertical  plans  plan  \
# 0     4.337232              6               0    14        26      5     5
# 1     4.337232              0               0     4        20     33    33
# 2     7.000000              0               0    14         8     31    31
# 3     4.337232              0               0    14         8     23    23
# 4     4.337232              0               0    14        20     23    23
# ...        ...            ...             ...   ...       ...    ...   ...
# 5884  4.337232              0               0     8        21     27    27
# 5885  4.337232              0               0     9        10     27    27
# 5886  4.337232              0               0     4        15     31    31
# 5887  4.337232              0               0     4        15     23    23
# 5888  4.337232              0               0     9        15     31    31
#
#       changing_platform  new_platform  salesperson  golive_days   url  \
# 0                     0             0           11           -1     0
# 1                     0             0           18           -1  4405
# 2                     0             0            8           -1  3971
# 3                     0             0           18           -1  2686
# 4                     0             0           20           -1  2605
# ...                 ...           ...          ...          ...   ...
# 5884                  0             0           24           -1  2143
# 5885                  0             0           24           -1  1246
# 5886                  0             0           24           -1  1249
# 5887                  0             0           24           -1  1343
# 5888                  0             0           24           -1  1588
#
#       churn_concern  cancelYear  cancelMonth  cancelWeek  cancelDay  \
# 0               0.0        2015            7          31         28
# 1               0.0        1970            1           1          1
# 2               0.0        1970            1           1          1
# 3               0.0        1970            1           1          1
# 4               0.0        1970            1           1          1
# ...             ...         ...          ...         ...        ...
# 5884            0.0        1970            1           1          1
# 5885            0.0        1970            1           1          1
# 5886            0.0        1970            1           1          1
# 5887            0.0        1970            1           1          1
# 5888            0.0        1970            1           1          1
#
#       cancelDayofweek  cancelDayofyear  cancelIs_month_end  \
# 0                   1              209               False
# 1                   3                1               False
# 2                   3                1               False
# 3                   3                1               False
# 4                   3                1               False
# ...               ...              ...                 ...
# 5884                3                1               False
# 5885                3                1               False
# 5886                3                1               False
# 5887                3                1               False
# 5888                3                1               False
#
#       cancelIs_month_start  cancelIs_quarter_end  cancelIs_quarter_start  \
# 0                    False                 False                   False
# 1                     True                 False                    True
# 2                     True                 False                    True
# 3                     True                 False                    True
# 4                     True                 False                    True
# ...                    ...                   ...                     ...
# 5884                  True                 False                    True
# 5885                  True                 False                    True
# 5886                  True                 False                    True
# 5887                  True                 False                    True
# 5888                  True                 False                    True
#
#       cancelIs_year_end  cancelIs_year_start  cancelElapsed  \
# 0                 False                False     1438041600
# 1                 False                 True              0
# 2                 False                 True              0
# 3                 False                 True              0
# 4                 False                 True              0
# ...                 ...                  ...            ...
# 5884              False                 True              0
# 5885              False                 True              0
# 5886              False                 True              0
# 5887              False                 True              0
# 5888              False                 True              0
#
#       licence_registration_Year  licence_registration_Month  \
# 0                          2010                           7
# 1                          2013                           7
# 2                          2013                           7
# 3                          2013                           7
# 4                          2013                           9
# ...                         ...                         ...
# 5884                       2019                           9
# 5885                       2019                           9
# 5886                       2019                           9
# 5887                       2019                           9
# 5888                       2019                           9
#
#       licence_registration_Week  licence_registration_Day  \
# 0                            26                         3
# 1                            29                        16
# 2                            29                        17
# 3                            29                        17
# 4                            37                        10
# ...                         ...                       ...
# 5884                         36                         4
# 5885                         36                         4
# 5886                         36                         5
# 5887                         36                         5
# 5888                         36                         6
#
#       licence_registration_Dayofweek  licence_registration_Dayofyear  \
# 0                                  5                             184
# 1                                  1                             197
# 2                                  2                             198
# 3                                  2                             198
# 4                                  1                             253
# ...                              ...                             ...
# 5884                               2                             247
# 5885                               2                             247
# 5886                               3                             248
# 5887                               3                             248
# 5888                               4                             249
#
#       licence_registration_Is_month_end  licence_registration_Is_month_start  \
# 0                                 False                                False
# 1                                 False                                False
# 2                                 False                                False
# 3                                 False                                False
# 4                                 False                                False
# ...                                 ...                                  ...
# 5884                              False                                False
# 5885                              False                                False
# 5886                              False                                False
# 5887                              False                                False
# 5888                              False                                False
#
#       licence_registration_Is_quarter_end  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 5884                                False
# 5885                                False
# 5886                                False
# 5887                                False
# 5888                                False
#
#       licence_registration_Is_quarter_start  licence_registration_Is_year_end  \
# 0                                     False                             False
# 1                                     False                             False
# 2                                     False                             False
# 3                                     False                             False
# 4                                     False                             False
# ...                                     ...                               ...
# 5884                                  False                             False
# 5885                                  False                             False
# 5886                                  False                             False
# 5887                                  False                             False
# 5888                                  False                             False
#
#       licence_registration_Is_year_start  licence_registration_Elapsed  \
# 0                                  False                    1278115200
# 1                                  False                    1373932800
# 2                                  False                    1374019200
# 3                                  False                    1374019200
# 4                                  False                    1378771200
# ...                                  ...                           ...
# 5884                               False                    1567555200
# 5885                               False                    1567555200
# 5886                               False                    1567641600
# 5887                               False                    1567641600
# 5888                               False                    1567728000
#
#       golive_Year  golive_Month  golive_Week  golive_Day  golive_Dayofweek  \
# 0            1970             1            1           1                 3
# 1            1970             1            1           1                 3
# 2            1970             1            1           1                 3
# 3            1970             1            1           1                 3
# 4            1970             1            1           1                 3
# ...           ...           ...          ...         ...               ...
# 5884         1970             1            1           1                 3
# 5885         1970             1            1           1                 3
# 5886         1970             1            1           1                 3
# 5887         1970             1            1           1                 3
# 5888         1970             1            1           1                 3
#
#       golive_Dayofyear  golive_Is_month_end  golive_Is_month_start  \
# 0                    1                False                   True
# 1                    1                False                   True
# 2                    1                False                   True
# 3                    1                False                   True
# 4                    1                False                   True
# ...                ...                  ...                    ...
# 5884                 1                False                   True
# 5885                 1                False                   True
# 5886                 1                False                   True
# 5887                 1                False                   True
# 5888                 1                False                   True
#
#       golive_Is_quarter_end  golive_Is_quarter_start  golive_Is_year_end  \
# 0                     False                     True               False
# 1                     False                     True               False
# 2                     False                     True               False
# 3                     False                     True               False
# 4                     False                     True               False
# ...                     ...                      ...                 ...
# 5884                  False                     True               False
# 5885                  False                     True               False
# 5886                  False                     True               False
# 5887                  False                     True               False
# 5888                  False                     True               False
#
#       golive_Is_year_start  golive_Elapsed  is_suspended_na
# 0                     True               0             True
# 1                     True               0            False
# 2                     True               0            False
# 3                     True               0            False
# 4                     True               0            False
# ...                    ...             ...              ...
# 5884                  True               0            False
# 5885                  True               0            False
# 5886                  True               0            False
# 5887                  True               0            False
# 5888                  True               0            False
#
# [5889 rows x 58 columns]
